# %%
import tifffile as tiff

# %%
img = tiff.imread("dstl/three_band/6040_2_2.tif") 
tiff.imshow(img)
# Out:
# (<Figure size 988.8x604.8 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x11d1048e0>)

# %%
img.shape
# Out:
# (3, 3349, 3391)
